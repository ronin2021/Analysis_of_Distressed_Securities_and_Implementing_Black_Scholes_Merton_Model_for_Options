# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
import datetime as dt
from pathlib import Path
import mibian as BS

# %matplotlib inline

# %%
#Read Hilton price data CSV file
csv_path = Path("./Resources/HLT_Closing_Price_Data.csv")
HLT_Closing_Price_Data = pd.read_csv(csv_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
HLT_Closing_Price_Data.sort_index(inplace=True)
HLT_Closing_Price_Data.columns = ["HLT"]
HLT_Closing_Price_Data.head()
# Out:
#               HLT
# Date
# 2018-01-02  79.68
# 2018-01-03  80.85
# 2018-01-04  80.25
# 2018-01-05  79.29
# 2018-01-08  80.94

# %%
#Read Marriott price data CSV file 
csv_path = Path("./Resources/MAR_Closing_Price_Data.csv")
MAR_Closing_Price_Data = pd.read_csv(csv_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
MAR_Closing_Price_Data.sort_index(inplace=True)
MAR_Closing_Price_Data.columns = ["MAR"]
MAR_Closing_Price_Data.head()
# Out:
#                MAR
# Date
# 2018-01-02  133.75
# 2018-01-03  136.45
# 2018-01-04  135.70
# 2018-01-05  134.40
# 2018-01-08  136.34

# %%
#Read S&P price data CSV file
csv_path = Path("./Resources/INX_Closing_Price_Data.csv")
INX_Closing_Price_Data = pd.read_csv(csv_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
INX_Closing_Price_Data.sort_index(inplace=True)
INX_Closing_Price_Data.columns = ["S&P"]
INX_Closing_Price_Data.head()
# Out:
#                 S&P
# Date
# 2018-01-02  2695.81
# 2018-01-03  2713.06
# 2018-01-04  2723.99
# 2018-01-05  2743.15
# 2018-01-08  2747.71

# %%
#Read 10 year treasury bill price data CSV file 
csv_path = Path("./Resources/TNX_Closing_Price_Data.csv")
TNX_Closing_Price_Data = pd.read_csv(csv_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
TNX_Closing_Price_Data.sort_index(inplace=True)
TNX_Closing_Price_Data.columns = ["TNX"]
TNX_Closing_Price_Data.head()
# Out:
#               TNX
# Date
# 2018-01-02  24.65
# 2018-01-03  24.47
# 2018-01-04  24.53
# 2018-01-05  24.76
# 2018-01-08  24.80

# %%
#Read American Airlines price data CSV file
csv_path = Path("./Resources/AAL_Closing_Price_Data.csv")
AAL_Closing_Price_Data = pd.read_csv(csv_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
AAL_Closing_Price_Data.sort_index(inplace=True)
AAL_Closing_Price_Data.columns = ["AAL"]
AAL_Closing_Price_Data.head()
# Out:
#               AAL
# Date
# 2018-01-02  52.99
# 2018-01-03  52.34
# 2018-01-04  52.67
# 2018-01-05  52.65
# 2018-01-08  52.13

# %%
#Read Delta price data CSV file 
csv_path = Path("./Resources/DAL_Closing_Price_Data.csv")
DAL_Closing_Price_Data = pd.read_csv(csv_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
DAL_Closing_Price_Data.sort_index(inplace=True)
DAL_Closing_Price_Data.columns = ["DAL"]
DAL_Closing_Price_Data.head()
# Out:
#               DAL
# Date
# 2018-01-02  56.74
# 2018-01-03  55.69
# 2018-01-04  55.69
# 2018-01-05  55.97
# 2018-01-08  54.68

# %%
#Read Carnival price data  file
csv_path = Path("./Resources/CCL_Closing_Price_Data.csv")
CCL_Closing_Price_Data = pd.read_csv(csv_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
CCL_Closing_Price_Data.sort_index(inplace=True)
CCL_Closing_Price_Data.columns = ["CCL"]
CCL_Closing_Price_Data.head()
# Out:
#               CCL
# Date
# 2018-01-02  66.75
# 2018-01-03  66.90
# 2018-01-04  66.85
# 2018-01-05  66.30
# 2018-01-08  66.05

# %%
#Read Royal Carribbean price data CSV file
csv_path = Path("./Resources/RCL_Closing_Price_Data.csv")
RCL_Closing_Price_Data = pd.read_csv(csv_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
RCL_Closing_Price_Data.sort_index(inplace=True)
RCL_Closing_Price_Data.columns = ["RCL"]
RCL_Closing_Price_Data.head()
# Out:
#                RCL
# Date
# 2018-01-02  120.38
# 2018-01-03  123.58
# 2018-01-04  122.46
# 2018-01-05  121.23
# 2018-01-08  121.09

# %%
#Read Dine Brands price data CSV file
csv_path = Path("./Resources/DIN_Closing_Price_Data.csv")
DIN_Closing_Price_Data = pd.read_csv(csv_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
DIN_Closing_Price_Data.sort_index(inplace=True)
DIN_Closing_Price_Data.columns = ["DIN"]
DIN_Closing_Price_Data.head()
# Out:
#               DIN
# Date
# 2018-01-02  51.94
# 2018-01-03  51.95
# 2018-01-04  51.71
# 2018-01-05  51.46
# 2018-01-08  50.59

# %%
#Read McDonald's price data CSV file 
csv_path = Path("./Resources/MCD_Closing_Price_Data.csv")
MCD_Closing_Price_Data = pd.read_csv(csv_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
MCD_Closing_Price_Data.sort_index(inplace=True)
MCD_Closing_Price_Data.columns = ["MCD"]
MCD_Closing_Price_Data.head()
# Out:
#                MCD
# Date
# 2018-01-02  173.22
# 2018-01-03  172.49
# 2018-01-04  173.70
# 2018-01-05  174.05
# 2018-01-08  173.93

# %%
#Calculate Carnival daily returns
CCL_returns_df = CCL_Closing_Price_Data.pct_change()
CCL_returns_df.dropna(inplace=True)
CCL_returns_df.head()
# Out:
#                  CCL
# Date
# 2018-01-03  0.002247
# 2018-01-04 -0.000747
# 2018-01-05 -0.008227
# 2018-01-08 -0.003771
# 2018-01-09  0.023921

# %%
#Calculate Royal Carribbean daily returns
RCL_returns_df = RCL_Closing_Price_Data.pct_change()
RCL_returns_df.dropna(inplace=True)
RCL_returns_df.head()
# Out:
#                  RCL
# Date
# 2018-01-03  0.026582
# 2018-01-04 -0.009063
# 2018-01-05 -0.010044
# 2018-01-08 -0.001155
# 2018-01-09  0.017012

# %%
#Calculate Hilton daily returns 
HLT_returns_df = HLT_Closing_Price_Data.pct_change()
HLT_returns_df.dropna(inplace=True)
HLT_returns_df.head()
# Out:
#                  HLT
# Date
# 2018-01-03  0.014684
# 2018-01-04 -0.007421
# 2018-01-05 -0.011963
# 2018-01-08  0.020810
# 2018-01-09  0.012231

# %%
#Calculate Marriott daily returns
MAR_returns_df = MAR_Closing_Price_Data.pct_change()
MAR_returns_df.dropna(inplace=True)
MAR_returns_df.head()
# Out:
#                  MAR
# Date
# 2018-01-03  0.020187
# 2018-01-04 -0.005497
# 2018-01-05 -0.009580
# 2018-01-08  0.014435
# 2018-01-09  0.010048

# %%
#Calculate S&P daily returns
INX_returns_df = INX_Closing_Price_Data.pct_change()
INX_returns_df.dropna(inplace=True)
INX_returns_df.head()
# Out:
#                  S&P
# Date
# 2018-01-03  0.006399
# 2018-01-04  0.004029
# 2018-01-05  0.007034
# 2018-01-08  0.001662
# 2018-01-09  0.001303

# %%
#Calculate Ten Year Treasury Bill daily returns
TNX_returns_df = TNX_Closing_Price_Data.pct_change()
TNX_returns_df.dropna(inplace=True)
TNX_returns_df.head()
# Out:
#                  TNX
# Date
# 2018-01-03 -0.007302
# 2018-01-04  0.002452
# 2018-01-05  0.009376
# 2018-01-08  0.001616
# 2018-01-09  0.026613

# %%
#Calculate American Airlines daily returns 
AAL_returns_df = AAL_Closing_Price_Data.pct_change()
AAL_returns_df.dropna(inplace=True)
AAL_returns_df.head()
# Out:
#                  AAL
# Date
# 2018-01-03 -0.012266
# 2018-01-04  0.006305
# 2018-01-05 -0.000380
# 2018-01-08 -0.009877
# 2018-01-09 -0.000959

# %%
#Calculate Delta daily returns
DAL_returns_df = DAL_Closing_Price_Data.pct_change()
DAL_returns_df.dropna(inplace=True)
DAL_returns_df.head()
# Out:
#                  DAL
# Date
# 2018-01-03 -0.018505
# 2018-01-04  0.000000
# 2018-01-05  0.005028
# 2018-01-08 -0.023048
# 2018-01-09 -0.009327

# %%
#Calculate Dine Brands daily returns 
DIN_returns_df = DIN_Closing_Price_Data.pct_change()
DIN_returns_df.dropna(inplace=True)
DIN_returns_df.head()
# Out:
#                  DIN
# Date
# 2018-01-03  0.000193
# 2018-01-04 -0.004620
# 2018-01-05 -0.004835
# 2018-01-08 -0.016906
# 2018-01-09 -0.030638

# %%
#Calculate Mcdonalds daily returns
MCD_returns_df = MCD_Closing_Price_Data.pct_change()
MCD_returns_df.dropna(inplace=True)
MCD_returns_df.head()
# Out:
#                  MCD
# Date
# 2018-01-03 -0.004214
# 2018-01-04  0.007015
# 2018-01-05  0.002015
# 2018-01-08 -0.000689
# 2018-01-09 -0.002242

# %%
# Creating a single dataframe
all_daily_returns_df = pd.concat(
    [HLT_returns_df, 
     MAR_returns_df, 
     AAL_returns_df, 
     DAL_returns_df, 
     DIN_returns_df, 
     MCD_returns_df, 
     CCL_returns_df, 
     RCL_returns_df, 
     INX_returns_df, 
     TNX_returns_df], 
    axis='columns', 
    join='inner'
)
all_daily_returns_df.dropna(inplace=True)
all_daily_returns_df.sort_index(inplace=True)
all_daily_returns_df.head()
# Out:
#                  HLT       MAR       AAL       DAL       DIN       MCD  \
# Date
# 2018-01-03  0.014684  0.020187 -0.012266 -0.018505  0.000193 -0.004214
# 2018-01-04 -0.007421 -0.005497  0.006305  0.000000 -0.004620  0.007015
# 2018-01-05 -0.011963 -0.009580 -0.000380  0.005028 -0.004835  0.002015
# 2018-01-08  0.020810  0.014435 -0.009877 -0.023048 -0.016906 -0.000689
# 2018-01-09  0.012231  0.010048 -0.000959 -0.009327 -0.030638 -0.002242
#
#                  CCL       RCL       S&P       TNX
# Date
# 2018-01-03  0.002247  0.026582  0.006399 -0.007302
# 2018-01-04 -0.000747 -0.009063  0.004029  0.002452
# 2018-01-05 -0.008227 -0.010044  0.007034  0.009376
# 2018-01-08 -0.003771 -0.001155  0.001662  0.001616
# 2018-01-09  0.023921  0.017012  0.001303  0.026613

# %%
# Plotting the returns of the selected securities
ax = all_daily_returns_df.plot(figsize=(20,10))
ax.set_xlabel("Date", fontsize = 12)
ax.set_ylabel("Daily Returns", fontsize = 12)
ax.set_title("Daily Returns of The Portfolio of Pandemic Distressed Securities", fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Daily Returns of The Portfolio of Pandemic Distressed Securities')

# %%
#Returns Analysis
cumulative_returns_df = (1 + all_daily_returns_df).cumprod()
ax = cumulative_returns_df.plot(figsize=(20,10))
ax.set_xlabel("Date", fontsize = 12) 
ax.set_ylabel("Cumulative Returns", fontsize = 12) 
ax.set_title("Cumulative Returns of The Portfolio of Pandemic Distressed Securities", fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Cumulative Returns of The Portfolio of Pandemic Distressed Securities')

# %%
# Box plot to visually show risk
porfolio_column = ["HLT", "MAR", "AAL", "DAL", "DIN", "MCD", "CCL", "RCL", "S&P", "TNX"]

ax = all_daily_returns_df.boxplot(column = porfolio_column, figsize = (15,20), fontsize = 10)
ax.set_ylim(-0.075,0.075)
ax.set_ylabel("Returns Spread", fontsize = 12)
ax.set_xlabel("\nPortfolio", fontsize = 12)
ax.set_title("Daily Returns Statistics", fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Daily Returns Statistics')

# %%
# Calculate the daily returns standard deviations of all securities
standard_dev = all_daily_returns_df.std()
standard_dev.sort_values(inplace=True)
standard_dev
# Out:
# S&P    0.014041
# MCD    0.016549
# HLT    0.021782
# MAR    0.026476
# DAL    0.030907
# AAL    0.041230
# RCL    0.042226
# TNX    0.043228
# CCL    0.044449
# DIN    0.046577
# dtype: float64

# %%
# Calculate the rolling standard deviation for all securities using a 21-day window
rolling_stdev_plot = all_daily_returns_df.rolling(window=21).std()

# Plot the rolling standard deviation
ax = rolling_stdev_plot.plot(figsize=(20,10))

ax.set_ylabel("21 Day Rolling STD of Returns", fontsize = 12)
ax.set_xlabel("Date", fontsize = 12)
ax.set_title("21 Day Rolling Standard Deviation of Returns of the Portfolio of Pandemic Distressed Securities", fontsize = 14)
# Out:
# Text(0.5, 1.0, '21 Day Rolling Standard Deviation of Returns of the Portfolio of Pandemic Distressed Securities')

# %%
# Calculate 21-day rolling covariance of the portfolio vs. S&P 500

rolling_covariance_HLT = all_daily_returns_df['HLT'].rolling(window=21).cov(all_daily_returns_df['S&P'])
rolling_covariance_HLT.dropna(inplace=True)
rolling_covariance_MAR = all_daily_returns_df['MAR'].rolling(window=21).cov(all_daily_returns_df['S&P'])
rolling_covariance_MAR.dropna(inplace=True)
rolling_covariance_AAL = all_daily_returns_df['AAL'].rolling(window=21).cov(all_daily_returns_df['S&P'])
rolling_covariance_AAL.dropna(inplace=True)
rolling_covariance_DAL = all_daily_returns_df['DAL'].rolling(window=21).cov(all_daily_returns_df['S&P'])
rolling_covariance_DAL.dropna(inplace=True)
rolling_covariance_DIN = all_daily_returns_df['DIN'].rolling(window=21).cov(all_daily_returns_df['S&P'])
rolling_covariance_DIN.dropna(inplace=True)
rolling_covariance_MCD = all_daily_returns_df['MCD'].rolling(window=21).cov(all_daily_returns_df['S&P'])
rolling_covariance_MCD.dropna(inplace=True)
rolling_covariance_CCL = all_daily_returns_df['CCL'].rolling(window=21).cov(all_daily_returns_df['S&P'])
rolling_covariance_CCL.dropna(inplace=True)
rolling_covariance_RCL = all_daily_returns_df['CCL'].rolling(window=21).cov(all_daily_returns_df['S&P'])
rolling_covariance_RCL.dropna(inplace=True)
rolling_covariance_TNX = all_daily_returns_df['TNX'].rolling(window=21).cov(all_daily_returns_df['S&P'])
rolling_covariance_TNX.dropna(inplace=True)

# Calculate 21-day rolling variance of S&P 500 
rolling_variance_INX = all_daily_returns_df['S&P'].rolling(window=21).var()
rolling_variance_INX.dropna(inplace=True)

# Calculate 21-day rolling Beta of portfolio
rolling_beta_HLT = rolling_covariance_HLT / rolling_variance_INX
rolling_beta_MAR = rolling_covariance_MAR / rolling_variance_INX
rolling_beta_AAL = rolling_covariance_AAL / rolling_variance_INX
rolling_beta_DAL = rolling_covariance_DAL / rolling_variance_INX
rolling_beta_DIN = rolling_covariance_DIN / rolling_variance_INX
rolling_beta_MCD = rolling_covariance_MCD / rolling_variance_INX
rolling_beta_CCL = rolling_covariance_CCL / rolling_variance_INX
rolling_beta_RCL = rolling_covariance_RCL / rolling_variance_INX
rolling_beta_TNX = rolling_covariance_TNX / rolling_variance_INX

# Set the figure of the chart and plot each beta trend on the single figure
ax = rolling_beta_HLT.plot(figsize=(20,10))
rolling_beta_MAR.plot(ax=ax)
rolling_beta_AAL.plot(ax=ax)
rolling_beta_DAL.plot(ax=ax)
rolling_beta_DIN.plot(ax=ax)
rolling_beta_MCD.plot(ax=ax)
rolling_beta_CCL.plot(ax=ax)
rolling_beta_RCL.plot(ax=ax)
rolling_beta_TNX.plot(ax=ax)

ax.set_ylabel("Rolling Beta", fontsize = 12)
ax.set_xlabel("Date", fontsize = 12)
ax.set_title("Rolling 21-Day Beta of the Portfolio of Pandemic Distressed Securities", fontsize = 14)

ax.legend(['HLT', 
           'MAR', 
           'AAL', 
           'DAL', 
           'DIN', 'MCD', 'CCL', 'RCL', 'TNX'])

# %%
# Rolling 21-day means of returns
rolling_mean_HLT = all_daily_returns_df['HLT'].rolling(window=21).mean()
rolling_mean_HLT.dropna(inplace=True)
rolling_mean_MAR = all_daily_returns_df['MAR'].rolling(window=21).mean()
rolling_mean_MAR.dropna(inplace=True)
rolling_mean_AAL = all_daily_returns_df['AAL'].rolling(window=21).mean()
rolling_mean_AAL.dropna(inplace=True)
rolling_mean_DAL = all_daily_returns_df['DAL'].rolling(window=21).mean()
rolling_mean_DAL.dropna(inplace=True)
rolling_mean_DIN = all_daily_returns_df['DIN'].rolling(window=21).mean()
rolling_mean_DIN.dropna(inplace=True)
rolling_mean_MCD = all_daily_returns_df['MCD'].rolling(window=21).mean()
rolling_mean_MCD.dropna(inplace=True)
rolling_mean_CCL = all_daily_returns_df['CCL'].rolling(window=21).mean()
rolling_mean_CCL.dropna(inplace=True)
rolling_mean_RCL = all_daily_returns_df['RCL'].rolling(window=21).mean()
rolling_mean_RCL.dropna(inplace=True)
rolling_mean_INX = all_daily_returns_df['S&P'].rolling(window=21).mean()
rolling_mean_INX.dropna(inplace=True)


# Rolling 21-mean of the risk free rate
rolling_mean_TNX = all_daily_returns_df['TNX'].rolling(window=21).mean()
rolling_mean_TNX.dropna(inplace=True)

# Rolling 21-day std of returns
rolling_std_HLT = all_daily_returns_df['HLT'].rolling(window=21).std()
rolling_std_HLT.dropna(inplace=True)
rolling_std_MAR = all_daily_returns_df['MAR'].rolling(window=21).std()
rolling_std_MAR.dropna(inplace=True)
rolling_std_AAL = all_daily_returns_df['AAL'].rolling(window=21).std()
rolling_std_AAL.dropna(inplace=True)
rolling_std_DAL = all_daily_returns_df['DAL'].rolling(window=21).std()
rolling_std_DAL.dropna(inplace=True)
rolling_std_DIN = all_daily_returns_df['DIN'].rolling(window=21).std()
rolling_std_DIN.dropna(inplace=True)
rolling_std_MCD = all_daily_returns_df['MCD'].rolling(window=21).std()
rolling_std_MCD.dropna(inplace=True)
rolling_std_CCL = all_daily_returns_df['CCL'].rolling(window=21).std()
rolling_std_CCL.dropna(inplace=True)
rolling_std_RCL = all_daily_returns_df['RCL'].rolling(window=21).std()
rolling_std_RCL.dropna(inplace=True)
rolling_std_INX = all_daily_returns_df['S&P'].rolling(window=21).std()
rolling_std_INX.dropna(inplace=True)

# Rolling 21-day Sharpe ratio
rolling_sharp_HLT = (rolling_mean_HLT - rolling_mean_TNX) / rolling_std_HLT
rolling_sharp_MAR = (rolling_mean_MAR - rolling_mean_TNX) / rolling_std_MAR
rolling_sharp_AAL = (rolling_mean_AAL - rolling_mean_TNX) / rolling_std_AAL
rolling_sharp_DAL = (rolling_mean_DAL - rolling_mean_TNX) / rolling_std_DAL
rolling_sharp_DIN = (rolling_mean_DIN - rolling_mean_TNX) / rolling_std_DIN
rolling_sharp_MCD = (rolling_mean_MCD - rolling_mean_TNX) / rolling_std_MCD
rolling_sharp_CCL = (rolling_mean_CCL - rolling_mean_TNX) / rolling_std_CCL
rolling_sharp_RCL = (rolling_mean_RCL - rolling_mean_TNX) / rolling_std_RCL
rolling_sharp_INX = (rolling_mean_INX - rolling_mean_TNX) / rolling_std_INX

# Set the figure of the chart and plot each beta trend on the single figure
ax = rolling_sharp_HLT.plot(figsize=(20,10))
rolling_sharp_MAR.plot(ax=ax)
rolling_sharp_AAL.plot(ax=ax)
rolling_sharp_DAL.plot(ax=ax)
rolling_sharp_DIN.plot(ax=ax)
rolling_sharp_MCD.plot(ax=ax)
rolling_sharp_CCL.plot(ax=ax)
rolling_sharp_RCL.plot(ax=ax)
rolling_sharp_INX.plot(ax=ax)

# Plot the rolling 21-day Sharpe ratios 
ax.set_ylabel("Rolling Sharpe Ratio", fontsize = 12)
ax.set_xlabel("Date", fontsize = 12)
ax.set_title("Rolling 21-Day Sharpe Ratio of the Portfolio of Pandemic Distressed Securities", fontsize = 14)

ax.legend(['HLT', 
           'MAR', 
           'AAL', 
           'DAL', 
           'DIN', 'MCD', 'CCL', 'RCL', 'S&P'])

# %%
# Rolling 21-day Treynor ratio of securities
rolling_treynor_HLT = (rolling_mean_HLT - rolling_mean_TNX)/ rolling_beta_HLT
rolling_treynor_MAR = (rolling_mean_MAR - rolling_mean_TNX)/ rolling_beta_MAR
rolling_treynor_AAL = (rolling_mean_AAL - rolling_mean_TNX)/ rolling_beta_AAL
rolling_treynor_DAL = (rolling_mean_DAL - rolling_mean_TNX)/ rolling_beta_DAL
rolling_treynor_DIN = (rolling_mean_DIN - rolling_mean_TNX)/ rolling_beta_DIN
rolling_treynor_MCD = (rolling_mean_MCD - rolling_mean_TNX)/ rolling_beta_MCD
rolling_treynor_CCL = (rolling_mean_CCL - rolling_mean_TNX)/ rolling_beta_CCL
rolling_treynor_RCL = (rolling_mean_RCL - rolling_mean_TNX)/ rolling_beta_RCL

# Set the figure of the chart and plot each beta trend on the single figure
ax = rolling_treynor_HLT.plot(figsize=(20,10))
rolling_treynor_MAR.plot(ax=ax)
rolling_treynor_AAL.plot(ax=ax)
rolling_treynor_DAL.plot(ax=ax)
rolling_treynor_DIN.plot(ax=ax)
rolling_treynor_MCD.plot(ax=ax)
rolling_treynor_CCL.plot(ax=ax)
rolling_treynor_RCL.plot(ax=ax)

# Plot the rolling 21-day Sharpe ratios
ax.set_ylim(-0.5,0.5)
ax.set_ylabel("Rolling Traynor Ratio", fontsize = 12)
ax.set_xlabel("Date", fontsize = 12)
ax.set_title("Rolling 21-Day Traynor Ratio of the Portfolio of Pandemic Distressed Securities", fontsize = 14)

ax.legend(['HLT', 
           'MAR', 
           'AAL', 
           'DAL', 
           'DIN', 'MCD', 'CCL', 'RCL'])
